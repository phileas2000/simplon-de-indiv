# %%
import requests
from bs4 import BeautifulSoup
import os
from pathlib import Path
cwd=Path(os.getcwd())

# %%
import utile

# %%
import site
print(site.getsitepackages())
# Out:
# ['c:\\Users\\Utilisateur\\AppData\\Local\\Python\\pythoncore-3.11-64', 'c:\\Users\\Utilisateur\\AppData\\Local\\Python\\pythoncore-3.11-64\\Lib\\site-packages']

# %%
content=requests.get("http://www.volonte-d.com/techniques/luffy.php")
text=content.text
page_crew=BeautifulSoup(text)
page_crew=page_crew.find_all("b")
print(type(page_crew))
print(len(page_crew))
writing_path=cwd/Path("tech.html")
print(writing_path)
with open(writing_path,"wt") as f:
    f.write(str(page_crew))
# Out:
# <class 'bs4.element.ResultSet'>
# 50
# c:\Users\Utilisateur\Desktop\brief_3\simplon-de-2026-lyon-main\week_02\smallproject\tech.html
